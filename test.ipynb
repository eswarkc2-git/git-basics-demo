# %%
theater_capacity=350
max_tickets_allowed=15
min_age_allowed=12
final_bookings={"Total Bookings":0, "Total Tickets Sold":0,"Rejected Bookings":0,"Remaining Seats":0}
age_persons=[]
ip_age=0

# %%
print(final_bookings)
# Out:
# {'Total Bookings': 0, 'Total Tickets Sold': 0, 'Rejected Bookings': 0, 'Remaining Seats': 0}
